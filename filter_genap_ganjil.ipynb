# %% [markdown]
# <a href="https://colab.research.google.com/github/andika-debug/repo/blob/main/filter_genap_ganjil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("data.txt", "r") as file:
  for line in file:
    angka = int(line.strip())

    if angka % 2 == 0:
      print(angka, "Genap")
    else :
      print(angka, "Ganjil")
# Out:
# 10 Genap
# 17 Ganjil
# 2345 Ganjil
# 1234 Genap
# 1234543 Ganjil
# 17 Ganjil
# 1 Ganjil
# 5 Ganjil
# 7 Ganjil
